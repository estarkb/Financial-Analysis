# %% [markdown]
# ## **EURUSD**

# %%
#Importamos las Librerías necesarias

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.reset_orig()
import numpy as np
from datetime import datetime
start = datetime(2007,1,1)
import pandas_datareader.data as web
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:855: MatplotlibDeprecationWarning:
# examples.directory is deprecated; in the future, examples will be found relative to the 'datapath' directory.
#   "found relative to the 'datapath' directory.".format(key))
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py:846: MatplotlibDeprecationWarning:
# The text.latex.unicode rcparam was deprecated in Matplotlib 2.2 and will be removed in 3.1.
#   "2.2", name=key, obj_type="rcparam", addendum=addendum)

# %% [markdown]
# ### **Paridad**

# %%
#EURUSD
par = web.get_data_fred(["DEXUSEU"], start)
par = par.fillna(method="ffill")
par.index = pd.to_datetime(par.index)
par.plot(figsize=(20,5))
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ###**Lado Euro**

# %% [markdown]
# ####**Tasa Libre de Riesgo**

# %%
#Risk Free
ger_rates = web.get_data_fred(["IRLTLT01DEM156N", "IR3TIB01DEM156N"], start)
ger_rates = ger_rates.fillna(method="ffill")
ger_rates.index = pd.to_datetime(ger_rates.index)
ger_rates.plot(figsize=(20,5))
plt.axhline(0, color='black', linewidth=1)
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Bolsa Alemana**

# %%
"""Obtener datos desde Yahoo"""
#Bolsas
dax = web.get_data_yahoo(["^GDAXI"], start).fillna(method="ffill")
dax = dax["Close"]
dax = dax.pct_change(1) +1
dax = dax.cumprod()
dax.index = pd.to_datetime(dax.index)
dax.plot(figsize=(20,5))
plt.axhline(1, color='black', linewidth=1)
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**GDP Alemania**

# %%
#gdp
start1=datetime(2006,1,1)
gdp = web.get_data_fred(["CLVMNACSCAB1GQDE"], start1)
gdp = gdp.fillna(method="ffill")
gdp.index = pd.to_datetime(gdp.index)
gdp = gdp.pct_change(4)
gdp.plot(figsize=(20,5))
plt.axhline(0, color='black', linewidth=1)
plt.title("Crecimiento GDP Alemania anual")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Empleo Alemania**

# %%
#empleo
empleo = web.get_data_fred(["LMUNRRTTDEA156N"], start)
empleo = empleo.fillna(method="ffill")
empleo.index = pd.to_datetime(empleo.index)
empleo.plot(figsize=(20,5))
plt.title("Desempleo")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Producción Industrial**

# %%
#Producción Industrial 2015=100
indpro = web.get_data_fred(["DEUPROINDMISMEI"], start)
indpro = indpro.fillna(method="ffill")
indpro.index = pd.to_datetime(indpro.index)
indpro.plot(figsize=(20,5))
plt.axhline(100, color='black', linewidth=1)
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ###**Lado Dólar**

# %% [markdown]
# ####**Tasa Libre de Riesgo**

# %%
#Risk Free
US_rates = web.get_data_fred(["DTB3", "DGS3MO", "DTB6", "DGS6MO", "DTB1YR", "DGS2", "DGS10"], start)
US_rates = US_rates.fillna(method="ffill")
US_rates.index = pd.to_datetime(US_rates.index)
US_rates.plot(figsize=(20,5))
plt.axhline(0, color='black', linewidth=1)
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Bolsa**

# %%
"""Obtener datos desde Yahoo"""
#Bolsas
bolsas = web.get_data_yahoo(["^GSPC", "^IXIC", "^DJI"], start).fillna(method="ffill")
bolsas = bolsas["Close"]
bolsas = bolsas.pct_change(1) +1
bolsas = bolsas.cumprod()
bolsas.index = pd.to_datetime(bolsas.index)
bolsas.plot(figsize=(20,5))
plt.axhline(1, color='black', linewidth=1)
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Crecimiento Estados Unidos**

# %%
#gdp
start1 = datetime(2006,1,1)
gdp = web.get_data_fred(["GDPC1"], start1)
gdp = gdp.fillna(method="ffill")
gdp.index = pd.to_datetime(gdp.index)
gdp = gdp.pct_change(4)
gdp.plot(figsize=(20,5))
plt.axhline(0, color='black', linewidth=1)
plt.title("Crecimiento GDP anual")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Empleo**

# %%
#empleo
empleo = web.get_data_fred(["UNRATE"], start)
empleo = empleo.fillna(method="ffill")
empleo.index = pd.to_datetime(empleo.index)
empleo.plot(figsize=(20,5))
plt.title("Desempleo")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Balanza de Pagos**

# %%
#Balanza de Pagos
tradebalance = web.get_data_fred(["BOPGSTB"], start)
tradebalance = tradebalance.fillna(method="ffill")
tradebalance.index = pd.to_datetime(tradebalance.index)
tradebalance.plot(figsize=(20,5))
plt.axhline(0, color='black', linewidth=1)
plt.title("Balanza de Pagos")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Deuda a PIB**

# %%
#deuda
deuda = web.get_data_fred(["GFDEGDQ188S"], start)
deuda = deuda.fillna(method="ffill")
deuda.index = pd.to_datetime(deuda.index)
deuda.plot(figsize=(20,5))
plt.title("Deuda como Porcentaje del PIB")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ####**Oferta de Dinero**

# %%
#dinero
dinero = web.get_data_fred(["M2"], start)
dinero = dinero.fillna(method="ffill")
dinero.index = pd.to_datetime(dinero.index)
dinero = dinero.pct_change(12)
dinero.plot(figsize=(20,5))
plt.title("Stock de Dinero, variación anual")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')

# %% [markdown]
# ###**Mundo**

# %%
mundo = web.get_data_fred(["GOLDAMGBD228NLBM", "DCOILWTICO", "BAMLC0A4CBBB", "VIXCLS"], start)
mundo = mundo.fillna(method="ffill")
mundo.index = pd.to_datetime(mundo.index)

fig0 = plt.figure(figsize=(15,5))
ax01 = fig0.add_subplot(2, 2, 1)
mundo["GOLDAMGBD228NLBM"].plot()
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')
plt.title("Oro")
ax02 = fig0.add_subplot(2, 2, 2)
mundo["DCOILWTICO"].plot(c="green")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')
plt.title("Petroleo")
ax02 = fig0.add_subplot(2, 2, 3)
mundo["BAMLC0A4CBBB"].plot(c="green")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')
plt.title("BBB")
plt.subplots_adjust(wspace=0.3, hspace=0.8)
ax02 = fig0.add_subplot(2, 2, 4)
mundo["VIXCLS"].plot(c="green")
plt.axvspan("2007-12-1", "2009-5-1", alpha=0.3, color='red')
plt.title("VIX")
plt.subplots_adjust(wspace=0.3, hspace=0.8)

# %%
start = datetime(2009,4,6)
dowgold = web.get_data_fred(["GOLDAMGBD228NLBM", "DJIA"], start)
dowgold = dowgold.fillna(method="ffill")
dowgold["ratio"] = dowgold["DJIA"]/dowgold["GOLDAMGBD228NLBM"]
dowgold.index = pd.to_datetime(dowgold.index)
dowgold = dowgold.pct_change(1)+1
dowgold= dowgold.cumprod()
dowgold["ratio"].plot(figsize=(20,5))
plt.axhline(1, color='black', linewidth=1)
plt.title("Crecimiento DowJones desde 6 de Abril de 2009 en relación al oro")
# Out:
# Text(0.5, 1.0, 'Crecimiento DowJones desde 6 de Abril de 2009 en relación al oro')
